# %% [markdown]
# <a href="https://colab.research.google.com/github/Contactashmeetsingh/waymo-mtr-/blob/main/waymo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sshaoshuai/MTR.git
# %cd MTR

# Install dependencies (This takes about 5-10 minutes)
# !pip install torch==1.12.1+cu113 torchvision==0.13.1+cu113 --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install waymo-open-dataset-tf-2-6-0==1.4.9
# !pip install -r requirements.txt

# Compile the custom CUDA kernels (Crucial for MTR++)
# !python setup.py develop
# Out:
# Cloning into 'MTR'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 110 (delta 19), reused 8 (delta 8), pack-reused 47 (from 1)
# Receiving objects: 100% (110/110), 509.47 KiB | 2.18 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# /content/MTR/MTR
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ERROR: Could not find a version that satisfies the requirement torch==1.12.1+cu113 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0)
# ERROR: No matching distribution found for torch==1.12.1+cu113
# ERROR: Could not find a version that satisfies the requirement waymo-open-dataset-tf-2-6-0==1.4.9 (from versions: none)
# ERROR: No matching distribution found for waymo-open-dataset-tf-2-6-0==1.4.9
# ...
# running develop
# ...
